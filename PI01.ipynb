# %%
import pandas as pd

# %%
#Importamos Datasets
pd.read_csv('Datasets/amazon_prime_titles.csv')
pd.read_csv('./Datasets/disney_plus_titles.csv')
pd.read_csv('./Datasets/hulu_titles.csv')
pd.read_json('./Datasets/netflix_titles.json')
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water             None
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans             None
# 4         s5  TV Show           Kota Factory             None
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb             None
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                  None  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#Guardamos archivos en variables de tipo dataframe.
df_amazon = pd.read_csv('Datasets/amazon_prime_titles.csv')
df_amazon.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
df_disney = pd.read_csv('./Datasets/disney_plus_titles.csv')
df_disney.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...

# %%
df_hulu = pd.read_csv('./Datasets/hulu_titles.csv')
df_hulu.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description
# ...

# %%
df_netflix = pd.read_json('./Datasets/netflix_titles.json')
df_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water             None
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans             None
# 4      s5  TV Show           Kota Factory             None
#
#                                                 cast        country  \
# 0                                               None  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           None
# 3                                               None           None
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#Creamos columna con el nombre de cada plataforma para incorporar al Dataframe unificado.
df_amazon['plataform'] = 'Amazon'
df_disney['plataform'] = 'Disney'
df_hulu['plataform'] = 'Hulu'
df_netflix['plataform'] = 'Netflix'

# %%
#Unimos Dataframes y probamos si hay duplicados eliminarlos
df_total = pd.concat([df_amazon, df_disney, df_hulu, df_netflix],ignore_index=True).drop_duplicates()

# %%
df_total
# Out:
#       show_id     type                 title         director  \
# 0          s1    Movie   The Grand Seduction     Don McKellar
# 1          s2    Movie  Take Care Good Night     Girish Joshi
# 2          s3    Movie  Secrets of Deception      Josh Webber
# 3          s4    Movie    Pink: Staying True   Sonia Anderson
# 4          s5    Movie         Monster Maker     Giles Foster
# ...       ...      ...                   ...              ...
# 22993   s8803    Movie                Zodiac    David Fincher
# 22994   s8804  TV Show           Zombie Dumb             None
# 22995   s8805    Movie            Zombieland  Ruben Fleischer
# 22996   s8806    Movie                  Zoom     Peter Hewitt
# 22997   s8807    Movie                Zubaan      Mozez Singh
#
#                                                     cast         country  \
# 0         Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
#Eliminamos columnas que no vamos a utilizar para las consultas que necesitamos.
df_total = df_total.drop(columns=['description', 'country', 'date_added', 'rating', 'show_id'])

# %%
df_total.head()
# Out:
#     type                 title        director  \
# 0  Movie   The Grand Seduction    Don McKellar
# 1  Movie  Take Care Good Night    Girish Joshi
# 2  Movie  Secrets of Deception     Josh Webber
# 3  Movie    Pink: Staying True  Sonia Anderson
# 4  Movie         Monster Maker    Giles Foster
#
#                                                 cast  release_year duration  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014  113 min
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018  110 min
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...          2017   74 min
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...          2014   69 min
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...          1989   45 min
#
#                  listed_in plataform
# 0            Comedy, Drama    Amazon
# 1     Drama, International    Amazon
# 2  Action, Drama, Suspense    Amazon
# 3              Documentary    Amazon
# ...

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22998 entries, 0 to 22997
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          22998 non-null  object
#  1   title         22998 non-null  object
#  2   director      14739 non-null  object
#  3   cast          17677 non-null  object
#  4   release_year  22998 non-null  int64
#  5   duration      22516 non-null  object
#  6   listed_in     22998 non-null  object
#  7   plataform     22998 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.6+ MB

# %%
#Contamos los nulos por filas
print(df_total.isna().sum(axis=1))
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 22993    0
# 22994    2
# 22995    0
# 22996    0
# 22997    0
# Length: 22998, dtype: int64

# %%
df_total.rename(columns={'type':'Tipo_film',  # Cambiamos los nombres de las columnas para leer mas claramente la informacion.
                    'title':'Titulo', 
                    'director':'Director',
                    'cast':'Reparto',
                    'release_year':'Ano_realizacion',
                    'duration':'Duracion',
                    'listed_in':'Genero',
                    'plataform':'Plataforma'}, inplace=True)

# %%
df_total['Indice'] = df_total.index #Asignamos ID unicos con los indices autoincrementables

# %%
df_total = df_total[['Indice','Titulo','Tipo_film','Ano_realizacion','Reparto','Duracion','Genero','Plataforma']] #Ordenamos las columnas

# %%
df_dur=df_total["Duracion"].str.split(expand=True) #Creamos un dataframe con los datos de la columna "duracion" separando el número de la unidad
df_dur.rename(columns={0:"Duracion",1:"tipo (min-Seasons)"},inplace=True) #Se renombran las columnas.
df_total.drop(columns='Duracion', inplace=True) #Se elimina la columna 'duracion' del dataframe original total.
df_total['Duracion'] = df_dur["Duracion"]   
df_total['tipo (min-Seasons)'] = df_dur['tipo (min-Seasons)']

# %%
#Se cambian los valores "sin dato" de las unidades de tiempo (minutos o seasons) en la columna correspondiente
df_total['tipo (min-Seasons)'][df_total['tipo (min-Seasons)'].loc[(df_total['Tipo_film']=='TV Show')].index]='season'
df_total['tipo (min-Seasons)'][df_total['tipo (min-Seasons)'].loc[(df_total['Tipo_film']=='Movie')].index] = 'min'
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18420\871342084.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total['tipo (min-Seasons)'][df_total['tipo (min-Seasons)'].loc[(df_total['Tipo_film']=='TV Show')].index]='season'
# C:\Users\HP\AppData\Local\Temp\ipykernel_18420\871342084.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total['tipo (min-Seasons)'][df_total['tipo (min-Seasons)'].loc[(df_total['Tipo_film']=='Movie')].index] = 'min'

# %%
df_total
# Out:
#        Indice                Titulo Tipo_film  Ano_realizacion  \
# 0           0   The Grand Seduction     Movie             2014
# 1           1  Take Care Good Night     Movie             2018
# 2           2  Secrets of Deception     Movie             2017
# 3           3    Pink: Staying True     Movie             2014
# 4           4         Monster Maker     Movie             1989
# ...       ...                   ...       ...              ...
# 22993   22993                Zodiac     Movie             2007
# 22994   22994           Zombie Dumb   TV Show             2018
# 22995   22995            Zombieland     Movie             2009
# 22996   22996                  Zoom     Movie             2006
# 22997   22997                Zubaan     Movie             2015
#
#                                                  Reparto  \
# 0         Brendan Gleeson, Taylor Kitsch, Gordon Pinsent
# 1       Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar
# ...

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22998 entries, 0 to 22997
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Indice              22998 non-null  int64
#  1   Titulo              22998 non-null  object
#  2   Tipo_film           22998 non-null  object
#  3   Ano_realizacion     22998 non-null  int64
#  4   Reparto             17677 non-null  object
#  5   Genero              22998 non-null  object
#  6   Plataforma          22998 non-null  object
#  7   Duracion            22516 non-null  object
#  8   tipo (min-Seasons)  22998 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 2.3+ MB

# %%
#Reemplazamos los nulos por 'Sin Dato' para optimizar la busqueda a excepcion de la columna duracion que reemplazamos por 0.
df_total['Duracion'].fillna(0, inplace=True)
df_total.fillna('Sin Dato', inplace=True)
df_total['Duracion']=df_total['Duracion'].astype('int64') #convertimos los datos de la columna Duracion a tipo entero.
df_total.head(10)
# Out:
#    Indice                 Titulo Tipo_film  Ano_realizacion  \
# 0       0    The Grand Seduction     Movie             2014
# 1       1   Take Care Good Night     Movie             2018
# 2       2   Secrets of Deception     Movie             2017
# 3       3     Pink: Staying True     Movie             2014
# 4       4          Monster Maker     Movie             1989
# 5       5  Living With Dinosaurs     Movie             1989
# 6       6              Hired Gun     Movie             2017
# 7       7           Grease Live!     Movie             2016
# 8       8        Global Meltdown     Movie             2017
# 9       9         David's Mother     Movie             1994
#
#                                              Reparto  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...
# ...

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22998 entries, 0 to 22997
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Indice              22998 non-null  int64
#  1   Titulo              22998 non-null  object
#  2   Tipo_film           22998 non-null  object
#  3   Ano_realizacion     22998 non-null  int64
#  4   Reparto             22998 non-null  object
#  5   Genero              22998 non-null  object
#  6   Plataforma          22998 non-null  object
#  7   Duracion            22998 non-null  int64
#  8   tipo (min-Seasons)  22998 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 2.3+ MB

# %%
df_total[(df_total['Duracion'] == 0) & (df_total['Plataforma'] == 'Hulu')]
# Out:
#        Indice                                             Titulo Tipo_film  \
# 11118   11118                     Ricky Velez: Here's Everything     Movie
# 11130   11130  Out of the Shadows: The Man Behind the Steele ...     Movie
# 11133   11133  Showtime Championship Boxing: Lopez vs. Salido...     Movie
# 11155   11155                  BELLATOR MMA: Kongo vs. Johnson 2     Movie
# 11158   11158                                      In the Crease     Movie
# ...       ...                                                ...       ...
# 14069   14069                                  All Saints (1998)     Movie
# 14073   14073                                         Getting On     Movie
# 14076   14076                                 (Sub) Ninja Scroll     Movie
# 14077   14077                              Packed to the Rafters     Movie
# 14111   14111                     Amy Winehouse: A Final Goodbye     Movie
#
# ...

# %%
# Calculamos el promedio de duracion por plataforma para completar los nulos con valores que no modifiquen las duraciones maximas de cada una filtrando por Plataforma y tipo de film

prom_pelicula = {}
prom_serie = {}
for plataforma in df_total['Plataforma'].unique():
    prom_pelicula[plataforma] = round(df_total[(df_total['Duracion'] !=0 ) & (df_total['Tipo_film']=='Movie') & (df_total['Plataforma'] == plataforma)]['Duracion'].mean())
    prom_serie[plataforma] = round(df_total[(df_total['Duracion'] !=0 ) & (df_total['Tipo_film']=='TV Show') & (df_total['Plataforma'] == plataforma)]['Duracion'].mean())
    df_total['Duracion'][df_total['Duracion'].loc[(df_total['Duracion'] ==0 ) & (df_total['Tipo_film']=='Movie') & (df_total['Plataforma'] == plataforma)].index] = prom_pelicula[plataforma]
    df_total['Duracion'][df_total['Duracion'].loc[(df_total['Duracion'] ==0 ) & (df_total['Tipo_film']=='TV Show') & (df_total['Plataforma'] == plataforma)].index] = prom_serie[plataforma]
print(prom_pelicula, prom_serie)
# Out:
# {'Amazon': 91, 'Disney': 72, 'Hulu': 98, 'Netflix': 100} {'Amazon': 2, 'Disney': 2, 'Hulu': 3, 'Netflix': 2}
# C:\Users\HP\AppData\Local\Temp\ipykernel_18420\306705968.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total['Duracion'][df_total['Duracion'].loc[(df_total['Duracion'] ==0 ) & (df_total['Tipo_film']=='Movie') & (df_total['Plataforma'] == plataforma)].index] = prom_pelicula[plataforma]
# C:\Users\HP\AppData\Local\Temp\ipykernel_18420\306705968.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_total.iloc[11118] # corroboramos algunas ubicaciones para ver que hayan cambiado los 0.
# Out:
# Indice                                         11118
# Titulo                Ricky Velez: Here's Everything
# Tipo_film                                      Movie
# Ano_realizacion                                 2021
# Reparto                                     Sin Dato
# Genero                              Comedy, Stand Up
# Plataforma                                      Hulu
# Duracion                                          98
# tipo (min-Seasons)                               min
# Name: 11118, dtype: object

# %%
df_total.columns
# Out:
# Index(['Indice', 'Titulo', 'Tipo_film', 'Ano_realizacion', 'Reparto', 'Genero',
#        'Plataforma', 'Duracion', 'tipo (min-Seasons)'],
#       dtype='object')

# %%
#Se cambian los valores "sin dato" de las unidades de tiempo (minutos o seasons) en la columna correspondiente
df_total['tipo (min-Seasons)'][df_total['tipo (min-Seasons)'].loc[(df_total['Tipo_film']=='TV Show')].index]='seasons'
df_total['tipo (min-Seasons)'][df_total['tipo (min-Seasons)'].loc[(df_total['Tipo_film']=='Movie')].index] = 'min'
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18420\2112341046.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total['tipo (min-Seasons)'][df_total['tipo (min-Seasons)'].loc[(df_total['Tipo_film']=='TV Show')].index]='seasons'
# C:\Users\HP\AppData\Local\Temp\ipykernel_18420\2112341046.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total['tipo (min-Seasons)'][df_total['tipo (min-Seasons)'].loc[(df_total['Tipo_film']=='Movie')].index] = 'min'

# %%
#Cambio de todos los textos en minusculas
df_total['Tipo_film']=df_total['Tipo_film'].str.lower()
df_total['Titulo']=df_total['Titulo'].str.lower()
df_total['Plataforma']=df_total['Plataforma'].str.lower()
df_total['Genero']=df_total['Genero'].str.lower()
df_total['Reparto']=df_total['Reparto'].str.lower()

# %%
df_total
# Out:
#        Indice                Titulo Tipo_film  Ano_realizacion  \
# 0           0   the grand seduction     movie             2014
# 1           1  take care good night     movie             2018
# 2           2  secrets of deception     movie             2017
# 3           3    pink: staying true     movie             2014
# 4           4         monster maker     movie             1989
# ...       ...                   ...       ...              ...
# 22993   22993                zodiac     movie             2007
# 22994   22994           zombie dumb   tv show             2018
# 22995   22995            zombieland     movie             2009
# 22996   22996                  zoom     movie             2006
# 22997   22997                zubaan     movie             2015
#
#                                                  Reparto  \
# 0         brendan gleeson, taylor kitsch, gordon pinsent
# 1       mahesh manjrekar, abhay mahajan, sachin khedekar
# ...

# %%
df_reparto=df_total["Reparto"].str.split(",",expand=True)

# %%
#Se convierten los actores en listas dentro del dataframe
df_total['Reparto_1'] = df_total['Reparto'].str.split("," or ":")
df_total.drop(columns=['Reparto'],inplace=True)
df_total.rename(columns={'Reparto_1':'Reparto'},inplace=True)

#creación de dataframe con todos los actores
actores = []
for cast in df_total['Reparto']:
    for actor in cast:
        actores.append(actor)

df_actors = pd.DataFrame(actores)
df_actors
# Out:
#                              0
# 0              brendan gleeson
# 1                taylor kitsch
# 2               gordon pinsent
# 3             mahesh manjrekar
# 4                abhay mahajan
# ...                        ...
# 119708        manish chaudhary
# 119709            meghna malik
# 119710           malkeet rauni
# 119711          anita shabdish
# 119712   chittaranjan tripathy
#
# [119713 rows x 1 columns]

# %%
#Creación de DataFrame para los actores
dic_actores = {'actor':[],
                'year':[],
                'plataforma':[]} #Se crea un diccionario para luego ser convertido en dataframe
for index, actors in enumerate(df_total['Reparto']):
    for actor in actors:
        dic_actores['actor'].append(actor) #Se agrega el actor al diccionario
        dic_actores['year'].append(df_total['Ano_realizacion'][index]) #Se agrega el año correspondiente actor al diccionario
        dic_actores['plataforma'].append(df_total['Plataforma'][index]) #Se agrega la plataforma correspondiente al actor al diccionario
df_actores = pd.DataFrame(dic_actores)
#df_actors=df_actors.drop_duplicates().reset_index()

# %%
df_total['Genero_1'] = df_total["Genero"].str.split(",")
df_total.drop(columns=['Genero'],inplace=True)
df_total.rename(columns={'Genero_1':'Genero'}, inplace=True)

# %%
#Creación de DataFrame para los generos
dic_genero = {'genero':[],
                'plataforma':[]} #Se crea un diccionario para luego ser convertido en dataframe
for index, generos in enumerate(df_total['Genero']):
    for genero in generos:
        dic_genero['genero'].append(genero) #Se agrega el genero al diccionario
        dic_genero['plataforma'].append(df_total['Plataforma'][index])
df_genero = pd.DataFrame(dic_genero)

# %%
df_genero
# Out:
#                          genero plataforma
# 0                        comedy     amazon
# 1                         drama     amazon
# 2                         drama     amazon
# 3                 international     amazon
# 4                        action     amazon
# ...                         ...        ...
# 48298  children & family movies    netflix
# 48299                  comedies    netflix
# 48300                    dramas    netflix
# 48301      international movies    netflix
# 48302          music & musicals    netflix
#
# [48303 rows x 2 columns]

# %%
df_actores.to_csv('actores.csv')
df_genero.to_csv('generos.csv')
df_total.to_csv('general.csv')

# %% [markdown]
# Codigos para plasmar en la API

# %%
def get_max_duration(año:int, plataforma:str, tipo_duracion:str):
    return {df_total[(df_total['Ano_realizacion']==año)&(df_total['Plataforma']==plataforma)&(df_total['tipo (min-Seasons)']== tipo_duracion)]['Duracion'].max()}

# %%
get_max_duration(2000, 'amazon', 'min')
# Out:
# {177}

# %%
def get_count_plataform(plataforma:str):   
    return{f"Cantidad de películas en {plataforma} es":df_total[(df_total['Plataforma']==plataforma)&(df_total['Tipo_film']=='movie')]['Tipo_film'].count(),
    f"Cantidad de series en {plataforma} es":df_total[(df_total['Plataforma']==plataforma)&(df_total['Tipo_film']=='tv show')]['Tipo_film'].count()}

# %%
get_count_plataform('amazon')
# Out:
# {'Cantidad de películas en amazon es': 7814,
#  'Cantidad de series en amazon es': 1854}

# %%
def get_listedin(genero:str):
    list_genero = []
    for plataforma in df_total['Plataforma'].unique():
        list_genero.append(df_genero[(df_genero['genero']==genero)&(df_genero['plataforma']==plataforma)].shape[0])
    
    maximo = max(list_genero)
    if list_genero.index(maximo)==0:
        return {'amazon': maximo}
    elif list_genero.index(maximo)==1:
        return {'disney': maximo}
    elif list_genero.index(maximo)==2:
        return {'hulu': maximo}
    elif list_genero.index('netflix',maximo)==2:
        return {'netflix': maximo}

# %%
get_listedin('drama')
# Out:
# {'amazon': 2216}

# %%
def get_actor(plataforma:str, año:int):
    data = df_actores[(df_actores['year']==año)&(df_actores['plataforma']==plataforma)]['actor']
    # return {data.value_counts().max()}
    if data.value_counts().index[0] == 'sin dato':
        return {data.value_counts().index[1]:data.value_counts()[1]}
    elif data.value_counts().index[0] != 'sin dato':
        return {data.value_counts().index[0]:data.value_counts()[0]}

# %%
get_actor('netflix', 2010)
# Out:
# {' zoe saldana': 3}

# %%
#Ingesto datos en tabla de SQL para realizar algunas consultas y ver mejor la tabla gral. A modo de consulta personal
#from sqlalchemy import create_engine
#engine = create_engine('mysql+pymysql://root:root@localhost/PI1')

#df_total.to_sql('Tablacompleta',con=engine,index=False,if_exists='replace')

# %%
df_actores
# Out:
#                          actor  year plataforma
# 0              brendan gleeson  2014     amazon
# 1                taylor kitsch  2014     amazon
# 2               gordon pinsent  2014     amazon
# 3             mahesh manjrekar  2018     amazon
# 4                abhay mahajan  2018     amazon
# ...                        ...   ...        ...
# 119708        manish chaudhary  2015    netflix
# 119709            meghna malik  2015    netflix
# 119710           malkeet rauni  2015    netflix
# 119711          anita shabdish  2015    netflix
# 119712   chittaranjan tripathy  2015    netflix
#
# [119713 rows x 3 columns]

# %%
df_total['tipo (min-Seasons)']
# Out:
# 0            min
# 1            min
# 2            min
# 3            min
# 4            min
#           ...
# 22993        min
# 22994    seasons
# 22995        min
# 22996        min
# 22997        min
# Name: tipo (min-Seasons), Length: 22998, dtype: object

# %%
pip freeze
# Out:
# anyio==3.6.2
# asttokens==2.0.8
# backcall==0.2.0
# certifi==2022.9.24
# charset-normalizer==2.1.1
# click==8.1.3
# colorama==0.4.5
# contourpy==1.0.6
# cycler==0.11.0
# debugpy==1.6.3
# decorator==5.1.1
# entrypoints==0.4
# executing==1.1.0
# fastapi==0.88.0
# fonttools==4.38.0
# greenlet==2.0.1
# h11==0.14.0
# idna==3.4
# ipykernel==6.16.0
# ipython==8.5.0
# jedi==0.18.1
# joblib==1.2.0
# jupyter-core==4.11.1
# jupyter_client==7.3.5
# kiwisolver==1.4.4
# kneed==0.8.1
# matplotlib==3.6.2
# matplotlib-inline==0.1.6
# nest-asyncio==1.5.6
# numpy==1.23.3
# packaging==21.3
# pandas==1.5.0
# parso==0.8.3
# pickleshare==0.7.5
# Pillow==9.3.0
# prompt-toolkit==3.0.31
# psutil==5.9.2
# pure-eval==0.2.2
# pyarrow==10.0.0
# pydantic==1.10.2
# Pygments==2.13.0
# PyMySQL==1.0.2
# pyparsing==3.0.9
# python-dateutil==2.8.2
# python-multipart==0.0.5
# pytz==2022.4
# pywin32==304
# pyzmq==24.0.1
# requests==2.28.1
# scikit-learn==1.1.3
# scipy==1.9.1
# seaborn==0.12.1
# six==1.16.0
# ...

# %%
http://127.0.0.1:8000/docs#/
# Out:
#   Cell In [51], line 1
#     http://127.0.0.1:8000/docs#/
#          ^
# SyntaxError: invalid syntax
